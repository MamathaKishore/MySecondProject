# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### Importing Dataframes

# %%
# Create path for df
path = r'C:\Users\mk106\OneDrive\Desktop\Mamatha courses and certificates\Instacart Basket Analysis'

# %%
#importing df
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_updated.pkl'))

# %%
# creating a subset of ords_prods_merge
df =  ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 20)

# %%
df.head(10)
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
# 5   3367565        1    prior             6                   2
# 6    550135        1    prior             7                   1
# 7   3108588        1    prior             8                   1
# 8   2295261        1    prior             9                   1
# 9   2550362        1    prior            10                   4
#
#    order_hour_of_day  days_since_last_order  product_id  add_to_cart_order  \
# 0                  8                    NaN         196                  1
# 1                  7                   15.0         196                  1
# ...

# %%
# Grouping Data with pandas
df.groupby('product_name')

# %%
# Aggregating Data with agg()
df.groupby('department_id').agg({'order_number' : ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                14.974233
# 3                18.300079
# 4                18.765849
# 6                16.470395
# 7                17.890720
# 11               21.682310
# 12               16.924342
# 13               17.907075
# 14               16.964049
# 15               18.233493
# 16               18.116992
# 17               10.552279
# 19               17.504216
# 20               17.251314

# %%
# Performing Multiple aggregations
df.groupby('department_id').agg({'order_number' : ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                14.974233   1  99
# 3                18.300079   1  99
# 4                18.765849   1  99
# 6                16.470395   1  90
# 7                17.890720   1  99
# 11               21.682310   1  99
# 12               16.924342   1  95
# 13               17.907075   1  99
# 14               16.964049   1  99
# 15               18.233493   1  99
# 16               18.116992   1  99
# 17               10.552279   1  98
# 19               17.504216   1  99
# 20               17.251314   1  99

# %% [markdown]
# #### Create a loyalty flag using loc

# %%
# Aggregating Data with transform
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0    2539329        1    prior             1                   2
# 1    2398795        1    prior             2                   3
# 2     473747        1    prior             3                   3
# 3    2254736        1    prior             4                   4
# 4     431534        1    prior             5                   4
# 5    3367565        1    prior             6                   2
# 6     550135        1    prior             7                   1
# 7    3108588        1    prior             8                   1
# 8    2295261        1    prior             9                   1
# 9    2550362        1    prior            10                   4
# 10   2968173       15    prior            15                   1
# 11   1870022       15    prior            17                   2
# 12   1911383       15    prior            18                   2
# ...

# %%
#Deriving coulmns with loc()
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    4869925
# Loyal customer      3157406
# New customer        1900070
# Name: count, dtype: int64

# %%
# checking the columns
ords_prods_merge[['user_id', 'order_number', 'loyalty_flag']].sample(30)
# Out:
#          user_id  order_number      loyalty_flag
# 8138487    28556            32    Loyal customer
# 712115     47631            64    Loyal customer
# 3876943    45006            18  Regular customer
# 7577235    46748            21  Regular customer
# 266313      4168             5  Regular customer
# 1666342    43830             8  Regular customer
# 9801715    21873             1      New customer
# 5303011    18488            25    Loyal customer
# 3303580    51470            60    Loyal customer
# 4113145    33697             2      New customer
# 9511096     8283            10  Regular customer
# 6389241     1680            12    Loyal customer
# 7731982    30548            10  Regular customer
# 2200710    24579             5  Regular customer
# 7493292    42826            36    Loyal customer
# 7351533    62514             2  Regular customer
# 5427962    51722             3      New customer
# 8984446    59309             3  Regular customer
# ...

# %% [markdown]
# ## Task_4.8 Aggregating Variables

# %%
#finding the aggregated mean of the "order_number" column grouped by the "department_id"
ords_prods_merge.groupby('department_id').agg({'order_number' : ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.395181
# 2                17.000546
# 3                17.228065
# 4                17.714601
# 5                14.956241
# 6                16.454727
# 7                17.325879
# 8                15.118831
# 9                16.027829
# 10               20.229811
# 11               16.454505
# 12               15.895299
# 13               16.692645
# 14               16.801500
# 15               16.133323
# 16               17.605789
# 17               15.936598
# 18               19.646685
# 19               17.216008
# 20               16.393918
# 21               22.580576

# %%
# reran df for comparison 
df.groupby('department_id').agg({'order_number' : ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                14.974233
# 3                18.300079
# 4                18.765849
# 6                16.470395
# 7                17.890720
# 11               21.682310
# 12               16.924342
# 13               17.907075
# 14               16.964049
# 15               18.233493
# 16               18.116992
# 17               10.552279
# 19               17.504216
# 20               17.251314

# %% [markdown]
# ### Question 3: Analyze the result. How do the results for the entire dataframe differ from those of the subset? Include your comments in a markdown cell below the executed code.

# %% [markdown]
# #### Except for the mean associated with 'department_id 17', the mean from 'order_number' exceeds the mean of the entire dataset.

# %% [markdown]
# ### Question 4: Follow the instructions in the Exercise for creating a loyalty flag for existing customers using the transform() and loc() functions.

# %% [markdown]
# #### Answer: completed. Output 23

# %% [markdown]
# ### Question 5. Basic stats of product prices for each loyalty category

# %%
# finding the mean, maximum, and minimum for the 3 loyalty categories
ords_prods_merge.groupby('loyalty_flag').agg({'prices' : ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer     9.438497  1.0  99999.0
# New customer      12.705941  1.0  99999.0
# Regular customer  11.676992  1.0  99999.0

# %% [markdown]
# ### Question 6: Create a spending flag for each user based on the average price across all their orders

# %% [markdown]
# #### Consumers whose average expenditure on purchased products is less than 10 are classified as "low spenders", while those whose average expenditure is equal to or greater than 10 are labeled "high spenders".

# %%
# creating "average_price" column 
ords_prods_merge['average_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_last_order  product_id  add_to_cart_order  \
# 0                  8                    NaN         196                  1
# 1                  7                   15.0         196                  1
# 2                 12                   21.0         196                  1
# 3                  7                   29.0         196                  1
# 4                 15                   28.0         196                  1
#
#    reordered  ... prices  _merge   price_range_loc    price_range_loc  \
# ...

# %%
# creating "Spending_flag" for average price < 10 as low spender
ords_prods_merge.loc[ords_prods_merge['average_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
#creating "Spending_flag" for average price >= 10 as High spender
ords_prods_merge.loc[ords_prods_merge['average_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# spending_flag
# Low spender     9744674
# High spender     182727
# Name: count, dtype: int64

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_last_order  product_id  add_to_cart_order  \
# 0                  8                    NaN         196                  1
# 1                  7                   15.0         196                  1
# 2                 12                   21.0         196                  1
# 3                  7                   29.0         196                  1
# 4                 15                   28.0         196                  1
#
#    reordered  ... _merge   price_range_loc    price_range_loc     busiest_day  \
# ...

# %% [markdown]
# ### Question 7: Create order frequency flag that marks the regularity of a user's ordering behavior.

# %% [markdown]
# #### 1. Customers with a median "days_since_prior_order" greater than 20 are classified as "infrequent customers".
# #### 2. Between 10 and 20 customers (inclusive) are designated as "regular customers".
# #### 3. Customers with a median equal to or less than 10 are assigned the label "Frequent Customers".

# %%
#creating "median_orders" column 
ords_prods_merge['median_orders'] = ords_prods_merge.groupby(['user_id'])['days_since_last_order'].transform(np.median)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_last_order  product_id  add_to_cart_order  \
# 0                  8                    NaN         196                  1
# 1                  7                   15.0         196                  1
# 2                 12                   21.0         196                  1
# 3                  7                   29.0         196                  1
# 4                 15                   28.0         196                  1
#
#    reordered  ...  price_range_loc    price_range_loc     busiest_day  \
# ...

# %%
# Creating "order_frequency_flag" for median_orders > 20 as "Non-frequent customer"
ords_prods_merge.loc[ords_prods_merge['median_orders'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'

# %%
# Creating "order_frequency_flag" for median orders > 10 & <= 20 as "Regular customer"
ords_prods_merge.loc[(ords_prods_merge['median_orders'] > 10) & (ords_prods_merge['median_orders'] <= 20), 'order_frequency_flag'] = 'Regular customer'

# %%
# Creating "order_frequency_flag" for median orders < 10 as "Frequent customer"
ords_prods_merge.loc[ords_prods_merge['median_orders'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
# checking "order_frequency_flag" frequency
ords_prods_merge['order_frequency_flag'].value_counts(dropna = False)
# Out:
# order_frequency_flag
# Frequent customer        6587627
# Regular customer         2228697
# Non-frequent customer    1111077
# Name: count, dtype: int64

# %% [markdown]
# ### Question 9: Export dataframe as pickle file and store it in your "Prepared Data" folder

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_updated_2.0.pkl'))
